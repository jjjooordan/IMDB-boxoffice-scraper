# %% [markdown]
# # Web Scraping Development
# ## IMDB Actor Filmography
#
# ## Objectives
# * To learn more about web scraping
# * To pull actor credits from filmography
# * To create a DataFrame containing film title and 'href' link for detailed data pull
# * Example used will be to pull actor filmography data from IMDB

# %%
# Install packages, if necessary
# pip install requests
# pip install beautifulsoup4

# %%
# Load libraries and URL:
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
# import numpy as np
# import seaborn as sns

# Example URL is for Tom Cruise:
url = 'https://www.imdb.com/name/nm0000129/'

# Load URL and confirm success by loading first 100 characters:
r = requests.get(url)
print(r.content[:100])

# Parse HTML with BeautifulSoup:
soup = BeautifulSoup(r.content, 'html.parser')
# Out:
# b'\n\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/200'

# %%
# Use Prettify HTML for manual review if necessary:
# print(soup.prettify())

# %%
# Manual review of Prettify HTML suggests all actor credits have:
# <div> tags
# 'id' attribute that starts with 'actor-'
# Note: code can be modified at this point to scrape other types of credits

# Within 'soup', find all <div> tag with 'id' attribute starting with 'actor-':
films = soup.find_all('div', id = re.compile('^actor-'))

# %%
# Review parsing accuracy:
for i in films:
    print(i.text) # Movie title
    print(i.get('href')) # Movie URL reference
# Out:
#  2021
#
# Mission: Impossible 7
# (announced)
#
# Ethan Hunt
#
# None
#
#
#
#
# Luna Park
# (announced)
#
#
# None
#
#
#
#
# Untitled Tom Cruise/SpaceX Project
# (announced)
#
#
# None
#
#
#  2022
#
# Mission: Impossible 8
# (announced)
#
# Ethan Hunt
#
# None
#
#
#
#
# Live Die Repeat and Repeat
# (pre-production)
#
# Cage (rumored)
#
# None
#
#
#  2021
#
# Top Gun: Maverick
# (post-production)
#
# Maverick
#
# None
#
#
#  2018
#
# Mission: Impossible - Fallout
#
# Ethan Hunt
#
# None
#
#
#  2017
#
# American Made
#
# Barry Seal
#
# None
#
#
#  2017
#
# The Mummy
#
# Nick Morton
#
# None
#
#
#  2016
#
# Jack Reacher: Never Go Back
#
# Jack Reacher
#
# None
#
#
#  2015
#
# Mission: Impossible - Rogue Nation
#
# Ethan Hunt
#
# None
#
#
#  2014
#
# Edge of Tomorrow
#
# Cage
#
# None
#
#
#  2013/I
#
# Oblivion
#
# Jack
#
# None
#
#
#  2012
#
# Jack Reacher
#
# Reacher
#
# None
#
#
#  2012
#
# Rock of Ages
#
# Stacee Jaxx
#
# None
#
#
#  2011
#
# Mission: Impossible - Ghost Protocol
#
# Ethan Hunt
#
# None
#
#
#  2010
#
# Knight and Day
#
# Roy Miller
#
# None
#
#
#  2008
#
# Valkyrie
#
# Colonel Claus von Stauffenberg
#
# None
#
#
#  2008
#
# Tropic Thunder
#
# Les Grossman - Grossman's Office
#
# None
#
#
#  2007
#
# Lions for Lambs
#
# Senator Jasper Irving
#
# None
#
#
#  2006
#
# Mission: Impossible III
#
# Ethan Hunt
#
# None
#
#
#  2005
#
# War of the Worlds
#
# Ray Ferrier
#
# None
#
#
#  2004
#
# Collateral
#
# Vincent
#
# None
#
#
#  2003
#
# The Last Samurai
#
# Nathan Algren
#
# None
#
#
#  2002
#
# Austin Powers in Goldmember
#
# Tom Cruise / Famous Austin ('Austinpussy')
#
# None
#
#
#  2002
#
# Minority Report
#
# Chief John Anderton
#
# None
#
#
#  2001
#
# Vanilla Sky
#
# David Aames
#
# None
#
#
#  2000
#
# Mission: Impossible II
#
# Ethan Hunt
#
# None
#
#
#  1999
#
# Magnolia
#
# Frank T.J. Mackey
#
# None
#
#
#  1999
#
# Aimee Mann: Save Me
# (Video short)
#
# Frank T.J. Mackey
#
# None
#
#
#  1999
#
# Eyes Wide Shut
#
# Dr. William Harford
#
# None
#
#
#  1996
#
# Jerry Maguire
#
# Jerry Maguire
#
# None
#
#
#  1996
#
# Mission: Impossible
#
# Ethan Hunt
#
# None
#
#
#  1994
#
# Interview with the Vampire: The Vampire Chronicles
#
# Lestat
#
# None
#
#
#  1993
#
# The Firm
#
# Mitch McDeere
#
# None
#
#
#  1992
#
# A Few Good Men
#
# Lt. Daniel Kaffee
#
# None
#
#
#  1992
#
# Far and Away
#
# Joseph Donnelly
#
# None
#
#
#  1990
#
# Days of Thunder
#
# Cole Trickle
#
# None
#
#
#  1989
#
# Born on the Fourth of July
#
# Ron Kovic
#
# None
#
#
#  1988
#
# Rain Man
#
# Charlie Babbitt
#
# None
#
#
#  1988
#
# Cocktail
#
# Brian Flanagan
#
# None
#
#
#  1986
#
# The Color of Money
#
# Vincent
#
# None
#
#
#  1986
#
# Top Gun
#
# Maverick
#
# None
#
#
#  1985
#
# Legend
#
# Jack
#
# None
#
#
#  1983
#
# All the Right Moves
#
# Stefen Djordjevic
#
# None
#
#
#  1983
#
# Risky Business
#
# Joel
#
# None
#
#
#  1983
#
# Losin' It
#
# Woody
#
# None
#
#
#  1983
#
# The Outsiders
#
# Steve Randle
#
# None
#
#
#  1981/I
#
# Taps
#
# David Shawn
#
# None
#
#
#  1981
#
# Endless Love
#
# Billy
#
# None

# %%
# Create new array, and append movie title and href:
filmsarray = []
for film in films:
    filmsarray.append([film.a.text, film.a.get('href')])

# Print array for review:
filmsarray
# Out:
# [['Mission: Impossible 7', '/title/tt9603212/'],
#  ['Luna Park', '/title/tt1123441/'],
#  ['Untitled Tom Cruise/SpaceX Project', '/title/tt12273460/'],
#  ['Mission: Impossible 8', '/title/tt9603208/'],
#  ['Live Die Repeat and Repeat', '/title/tt5617712/'],
#  ['Top Gun: Maverick', '/title/tt1745960/'],
#  ['Mission: Impossible - Fallout', '/title/tt4912910/'],
#  ['American Made', '/title/tt3532216/'],
#  ['The Mummy', '/title/tt2345759/'],
#  ['Jack Reacher: Never Go Back', '/title/tt3393786/'],
#  ['Mission: Impossible - Rogue Nation', '/title/tt2381249/'],
#  ['Edge of Tomorrow', '/title/tt1631867/'],
#  ['Oblivion', '/title/tt1483013/'],
#  ['Jack Reacher', '/title/tt0790724/'],
#  ['Rock of Ages', '/title/tt1336608/'],
#  ['Mission: Impossible - Ghost Protocol', '/title/tt1229238/'],
#  ['Knight and Day', '/title/tt1013743/'],
#  ['Valkyrie', '/title/tt0985699/'],
#  ['Tropic Thunder', '/title/tt0942385/'],
#  ['Lions for Lambs', '/title/tt0891527/'],
#  ['Mission: Impossible III', '/title/tt0317919/'],
#  ['War of the Worlds', '/title/tt0407304/'],
#  ['Collateral', '/title/tt0369339/'],
#  ['The Last Samurai', '/title/tt0325710/'],
#  ['Austin Powers in Goldmember', '/title/tt0295178/'],
#  ['Minority Report', '/title/tt0181689/'],
#  ['Vanilla Sky', '/title/tt0259711/'],
#  ['Mission: Impossible II', '/title/tt0120755/'],
#  ['Magnolia', '/title/tt0175880/'],
#  ['Aimee Mann: Save Me', '/title/tt5094696/'],
#  ['Eyes Wide Shut', '/title/tt0120663/'],
#  ['Jerry Maguire', '/title/tt0116695/'],
#  ['Mission: Impossible', '/title/tt0117060/'],
#  ['Interview with the Vampire: The Vampire Chronicles', '/title/tt0110148/'],
#  ['The Firm', '/title/tt0106918/'],
#  ['A Few Good Men', '/title/tt0104257/'],
#  ['Far and Away', '/title/tt0104231/'],
#  ['Days of Thunder', '/title/tt0099371/'],
#  ['Born on the Fourth of July', '/title/tt0096969/'],
#  ['Rain Man', '/title/tt0095953/'],
#  ['Cocktail', '/title/tt0094889/'],
#  ['The Color of Money', '/title/tt0090863/'],
#  ['Top Gun', '/title/tt0092099/'],
#  ['Legend', '/title/tt0089469/'],
#  ['All the Right Moves', '/title/tt0085154/'],
#  ['Risky Business', '/title/tt0086200/'],
#  ["Losin' It", '/title/tt0085868/'],
#  ['The Outsiders', '/title/tt0086066/'],
#  ['Taps', '/title/tt0083169/'],
#  ['Endless Love', '/title/tt0082329/']]

# %%
# Convert array to DataFrame with column titles:
pdfilms = pd.DataFrame(filmsarray, columns = ['Title', 'href'])
pdfilms
# Out:
#                                                 Title                href
# 0                               Mission: Impossible 7   /title/tt9603212/
# 1                                           Luna Park   /title/tt1123441/
# 2                  Untitled Tom Cruise/SpaceX Project  /title/tt12273460/
# 3                               Mission: Impossible 8   /title/tt9603208/
# 4                          Live Die Repeat and Repeat   /title/tt5617712/
# 5                                   Top Gun: Maverick   /title/tt1745960/
# 6                       Mission: Impossible - Fallout   /title/tt4912910/
# 7                                       American Made   /title/tt3532216/
# 8                                           The Mummy   /title/tt2345759/
# 9                         Jack Reacher: Never Go Back   /title/tt3393786/
# 10                 Mission: Impossible - Rogue Nation   /title/tt2381249/
# 11                                   Edge of Tomorrow   /title/tt1631867/
# 12                                           Oblivion   /title/tt1483013/
# 13                                       Jack Reacher   /title/tt0790724/
# 14                                       Rock of Ages   /title/tt1336608/
# 15               Mission: Impossible - Ghost Protocol   /title/tt1229238/
# 16                                     Knight and Day   /title/tt1013743/
# 17                                           Valkyrie   /title/tt0985699/
# 18                                     Tropic Thunder   /title/tt0942385/
# 19                                    Lions for Lambs   /title/tt0891527/
# 20                            Mission: Impossible III   /title/tt0317919/
# 21                                  War of the Worlds   /title/tt0407304/
# 22                                         Collateral   /title/tt0369339/
# 23                                   The Last Samurai   /title/tt0325710/
# 24                        Austin Powers in Goldmember   /title/tt0295178/
# 25                                    Minority Report   /title/tt0181689/
# 26                                        Vanilla Sky   /title/tt0259711/
# 27                             Mission: Impossible II   /title/tt0120755/
# 28                                           Magnolia   /title/tt0175880/
# 29                                Aimee Mann: Save Me   /title/tt5094696/
# 30                                     Eyes Wide Shut   /title/tt0120663/
# 31                                      Jerry Maguire   /title/tt0116695/
# 32                                Mission: Impossible   /title/tt0117060/
# 33  Interview with the Vampire: The Vampire Chroni...   /title/tt0110148/
# 34                                           The Firm   /title/tt0106918/
# 35                                     A Few Good Men   /title/tt0104257/
# 36                                       Far and Away   /title/tt0104231/
# 37                                    Days of Thunder   /title/tt0099371/
# 38                         Born on the Fourth of July   /title/tt0096969/
# 39                                           Rain Man   /title/tt0095953/
# 40                                           Cocktail   /title/tt0094889/
# 41                                 The Color of Money   /title/tt0090863/
# 42                                            Top Gun   /title/tt0092099/
# 43                                             Legend   /title/tt0089469/
# 44                                All the Right Moves   /title/tt0085154/
# 45                                     Risky Business   /title/tt0086200/
# 46                                          Losin' It   /title/tt0085868/
# 47                                      The Outsiders   /title/tt0086066/
# 48                                               Taps   /title/tt0083169/
# 49                                       Endless Love   /title/tt0082329/

# %% [markdown]
# ## Repeat to Check
# Repeat the same exercise but with another actor; in this case, Tom Hanks.
#
# Note: Tom Hanks' filmography section begins with Producer, instead of Actor.  This originally caused an issue and forced me to review how to search for Actor credits, only.

# %%
# Repeat for another actor to test:
# Example URL is for Tom Hanks:
url_test = 'https://www.imdb.com/name/nm0000158/'

# Load URL and confirm success:
r_test = requests.get(url_test)
# Verify by printing first 100 characters:
# print(r_test.content[:100])

# Parse HTML with BeautifulSoup:
soup_test = BeautifulSoup(r_test.content, 'html.parser')

# %%
# Prettify HTML for manual review:
# print(soup_test.prettify())

# Within 'soup_test', find all <div> tag with 'id' attribute starting with 'actor-':
films_test = soup_test.find_all('div', id = re.compile('^actor-'))

filmsarray_test = []
for film in films_test:
    filmsarray_test.append([film.a.text, film.a.get('href')])
filmsarray_test
# Out:
# [['Untitled Elvis Presley Project', '/title/tt3704428/'],
#  ['A Man Called Ove', '/title/tt7405458/'],
#  ['In the Garden of Beasts', '/title/tt2123969/'],
#  ['BIOS', '/title/tt3420504/'],
#  ['News of the World', '/title/tt6878306/'],
#  ['Greyhound', '/title/tt6048922/'],
#  ['A Beautiful Day in the Neighborhood', '/title/tt3224458/'],
#  ['Toy Story 4', '/title/tt1979376/'],
#  ['The Post', '/title/tt6294822/'],
#  ['The David S. Pumpkins Halloween Special', '/title/tt7452910/'],
#  ['The Circle', '/title/tt4287320/'],
#  ['Inferno', '/title/tt3062096/'],
#  ['Sully', '/title/tt3263904/'],
#  ['Maya & Marty', '/title/tt5543284/'],
#  ['A Hologram for the King', '/title/tt2980210/'],
#  ['Ithaca', '/title/tt3501590/'],
#  ['Bridge of Spies', '/title/tt3682448/'],
#  ['Carly Rae Jepsen: I Really Like You', '/title/tt7094450/'],
#  ['Toy Story That Time Forgot', '/title/tt3473654/'],
#  ['Saving Mr. Banks', '/title/tt2140373/'],
#  ['Toy Story of Terror', '/title/tt2446040/'],
#  ['Captain Phillips', '/title/tt1535109/'],
#  ['Partysaurus Rex', '/title/tt2340678/'],
#  ['Cloud Atlas', '/title/tt1371111/'],
#  ['Electric City', '/title/tt1746961/'],
#  ['Extremely Loud & Incredibly Close', '/title/tt0477302/'],
#  ['Small Fry', '/title/tt2033372/'],
#  ['The Daily Show', '/title/tt0115147/'],
#  ['Larry Crowne', '/title/tt1583420/'],
#  ['30 Rock', '/title/tt0496424/'],
#  ['Hawaiian Vacation', '/title/tt1850374/'],
#  ['Toy Story 3', '/title/tt0435761/'],
#  ['The Pacific', '/title/tt0374463/'],
#  ['Beyond All Boundaries', '/title/tt1448751/'],
#  ['Late Show with David Letterman', '/title/tt0106053/'],
#  ['Angels & Demons', '/title/tt0808151/'],
#  ['The Great Buck Howard', '/title/tt0460810/'],
#  ["Charlie Wilson's War", '/title/tt0472062/'],
#  ['The Simpsons Movie', '/title/tt0462538/'],
#  ['The Da Vinci Code', '/title/tt0382625/'],
#  ['Cars', '/title/tt0317219/'],
#  ['Magnificent Desolation: Walking on the Moon 3D', '/title/tt0401623/'],
#  ['The Polar Express', '/title/tt0338348/'],
#  ['Elvis Has Left the Building', '/title/tt0377057/'],
#  ['The Terminal', '/title/tt0362227/'],
#  ['The Ladykillers', '/title/tt0335245/'],
#  ['Freedom: A History of US', '/title/tt0361185/'],
#  ['Catch Me If You Can', '/title/tt0264464/'],
#  ['Road to Perdition', '/title/tt0257044/'],
#  ['Band of Brothers', '/title/tt0185906/'],
#  ['Cast Away', '/title/tt0162222/'],
#  ['The Green Mile', '/title/tt0120689/'],
#  ['Toy Story 2', '/title/tt0120363/'],
#  ["You've Got Mail", '/title/tt0128853/'],
#  ['Saving Private Ryan', '/title/tt0120815/'],
#  ['From the Earth to the Moon', '/title/tt0120570/'],
#  ['The Wonderful World of Disney', '/title/tt0132666/'],
#  ['That Thing You Do!', '/title/tt0117887/'],
#  ['Toy Story', '/title/tt0114709/'],
#  ['Apollo 13', '/title/tt0112384/'],
#  ['Vault of Horror I', '/title/tt0111594/'],
#  ['Forrest Gump', '/title/tt0109830/'],
#  ['Bruce Springsteen: Streets of Philadelphia', '/title/tt7116194/'],
#  ['Philadelphia', '/title/tt0107818/'],
#  ['Fallen Angels', '/title/tt0105994/'],
#  ['Sleepless in Seattle', '/title/tt0108160/'],
#  ['A League of Their Own', '/title/tt0104694/'],
#  ['Tales from the Crypt', '/title/tt0096708/'],
#  ['Radio Flyer', '/title/tt0105211/'],
#  ['The Bonfire of the Vanities', '/title/tt0099165/'],
#  ['Joe Versus the Volcano', '/title/tt0099892/'],
#  ['Turner & Hooch', '/title/tt0098536/'],
#  ["The 'Burbs", '/title/tt0096734/'],
#  ['Punchline', '/title/tt0095927/'],
#  ['Big', '/title/tt0094737/'],
#  ['Dan Aykroyd and Tom Hanks: City of Crime', '/title/tt11885402/'],
#  ['Dragnet', '/title/tt0092925/'],
#  ['Every Time We Say Goodbye', '/title/tt0091019/'],
#  ['Nothing in Common', '/title/tt0091653/'],
#  ['The Money Pit', '/title/tt0091541/'],
#  ['Volunteers', '/title/tt0090274/'],
#  ['The Man with One Red Shoe', '/title/tt0089543/'],
#  ['Bachelor Party', '/title/tt0086927/'],
#  ['Splash', '/title/tt0088161/'],
#  ['Family Ties', '/title/tt0083413/'],
#  ['Mazes and Monsters', '/title/tt0084314/'],
#  ['Happy Days', '/title/tt0070992/'],
#  ['Taxi', '/title/tt0077089/'],
#  ['Bosom Buddies', '/title/tt0080202/'],
#  ['The Love Boat', '/title/tt0075529/'],
#  ["He Knows You're Alone", '/title/tt0080850/']]

# %%
# Convert array to DataFrame with column titles:
pdfilms_test = pd.DataFrame(filmsarray_test, columns = ['Title', 'href'])
pdfilms_test
# Out:
#                              Title               href
# 0   Untitled Elvis Presley Project  /title/tt3704428/
# 1                 A Man Called Ove  /title/tt7405458/
# 2          In the Garden of Beasts  /title/tt2123969/
# 3                             BIOS  /title/tt3420504/
# 4                News of the World  /title/tt6878306/
# ..                             ...                ...
# 86                      Happy Days  /title/tt0070992/
# 87                            Taxi  /title/tt0077089/
# 88                   Bosom Buddies  /title/tt0080202/
# 89                   The Love Boat  /title/tt0075529/
# 90           He Knows You're Alone  /title/tt0080850/
#
# [91 rows x 2 columns]
